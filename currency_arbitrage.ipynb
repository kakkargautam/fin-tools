# %%
import pandas as pd 
import numpy as np
df = pd.read_csv("fx_rate_3.csv") 
print (df)
# Out:
#   Currency_A Currency_B  weight
# 0        USD        EUR    0.20
# 1        EUR        GBP    0.10
# 2        GBP        USD   -0.35

# %%
G = nx.from_pandas_edgelist(df,source='Currency_A', target='Currency_B', edge_attr=['weight'], create_using=nx.DiGraph())
nx.draw_circular(G, with_labels=True)
plt.show() 
print (G.edges['USD', 'EUR']['weight'])
# Out:
# 0.2

# %%
def find_path(digraph, start):
    try:
        path = nx.bellman_ford_predecessor_and_distance(digraph, start, 'weight') 
        print ("Positive")
        return path
    except NetworkXUnbounded:
        cycles = nx.simple_cycles(digraph)
        for cycle in cycles:
            print ("Negative")
            print (cycle)  ## do whatever you prefer here of course

# %%
find_path(G,'USD')
# Out:
# ---------------------------------------------------------------------------
# NetworkXUnbounded                         Traceback (most recent call last)
# <ipython-input-129-2a6851262aa8> in find_path(digraph, start)
#       2     try:
# ----> 3         path = nx.bellman_ford_predecessor_and_distance(digraph, start, 'weight')
#       4         print ("Positive")
#
# ~/anaconda3/envs/Virtual_Base/lib/python3.7/site-packages/networkx/algorithms/shortest_paths/weighted.py in bellman_ford_predecessor_and_distance(G, source, target, weight)
#    1202     dist = _bellman_ford(G, [source], weight, pred=pred, dist=dist,
# -> 1203                          target=target)
#    1204     return (pred, dist)
#
# ~/anaconda3/envs/Virtual_Base/lib/python3.7/site-packages/networkx/algorithms/shortest_paths/weighted.py in _bellman_ford(G, source, weight, pred, paths, dist, target)
#    1294                             raise nx.NetworkXUnbounded(
# -> 1295                                 "Negative cost cycle detected.")
#    1296                         count[v] = count_v
#
# NetworkXUnbounded: Negative cost cycle detected.
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-130-81a73309e30d> in <module>
# ----> 1 find_path(G,'USD')
#
# <ipython-input-129-2a6851262aa8> in find_path(digraph, start)
#       4         print ("Positive")
#       5         return path
# ----> 6     except NetworkXUnbounded:
#       7         cycles = nx.simple_cycles(digraph)
#       8         for cycle in cycles:
#
# NameError: name 'NetworkXUnbounded' is not defined

# %%
pos = nx.spring_layout(G)  
nx.draw_networkx_edges(G, pos, width=6)
nx.draw_networkx_nodes(G, pos, node_size=700)

# %%
#!/usr/bin/python
import networkx as nx
import matplotlib.pyplot as plt


pos = nx.spring_layout(G)  
nx.draw_networkx_edges(G, pos, width=6)
nx.draw_networkx_nodes(G, pos, node_size=700)

labels = nx.get_edge_attributes(G,'Rate_To')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
plt.savefig("abcd.jpg")

# %%
dgd = nx.floyd_warshall(G)

# %%
# Author: Aric Hagberg (hagberg@lanl.gov)
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()

G.add_edge('a', 'b', weight=0.6)
G.add_edge('a', 'c', weight=0.2)
G.add_edge('c', 'd', weight=0.1)
G.add_edge('c', 'e', weight=0.7)
G.add_edge('c', 'f', weight=0.9)
G.add_edge('a', 'd', weight=0.3)

elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] > 0.5]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] <= 0.5]

pos = nx.spring_layout(G)  # positions for all nodes

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge,
                       width=6)
nx.draw_networkx_edges(G, pos, edgelist=esmall,
                       width=6, alpha=0.5, edge_color='b', style='dashed')

# labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family='sans-serif')

plt.axis('off')
plt.show()

dgd = nx.floyd_warshall(G)

# %%
# Author: Aric Hagberg (hagberg@lanl.gov)
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()

G.add_edge('a', 'b', weight=-0.6)
G.add_edge('b', 'c', weight=0.2)
G.add_edge('c', 'a', weight=0.1)

elarge = [(u, v) for (u, v, d) in G.edges(data=True)]

pos = nx.spring_layout(G)  # positions for all nodes

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge,
                       width=6)

# labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family='sans-serif')

plt.axis('off')
plt.show()




def find_path(digraph, start):
    try:
        path = nx.bellman_ford(digraph, start) 
        return path
    except NetworkXUnbounded:
        cycles = nx.simple_cycles(digraph)
        for cycle in cycles:
            print (cycle) 
            

find_path(G,'a')

NetworkXUnbounded
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-abe52c037952> in find_path(digraph, start)
#      32     try:
# ---> 33         path = nx.bellman_ford(digraph, start)
#      34         return path
#
# AttributeError: module 'networkx' has no attribute 'bellman_ford'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-abe52c037952> in <module>
#      39
#      40
# ---> 41 find_path(G,'a')
#      42
#
# <ipython-input-65-abe52c037952> in find_path(digraph, start)
#      33         path = nx.bellman_ford(digraph, start)
#      34         return path
# ---> 35     except NetworkXUnbounded:
#      36         cycles = nx.simple_cycles(digraph)
#      37         for cycle in cycles:
#
# NameError: name 'NetworkXUnbounded' is not defined

# %%
# Author: Aric Hagberg (hagberg@lanl.gov)
import matplotlib.pyplot as plt
import networkx as nx

G = nx.Graph()

G.add_edge('a', 'b', weight=-0.6)
G.add_edge('b', 'c', weight=0.2)
G.add_edge('c', 'a', weight=0.1)

elarge = [(u, v) for (u, v, d) in G.edges(data=True)]

pos = nx.spring_layout(G)  # positions for all nodes

# nodes
nx.draw_networkx_nodes(G, pos, node_size=700)

# edges
nx.draw_networkx_edges(G, pos, edgelist=elarge,
                       width=6)

# labels
nx.draw_networkx_labels(G, pos, font_size=20, font_family='sans-serif')

plt.axis('off')
plt.show()

nx.simple_cycles(G)
# Out:
# ---------------------------------------------------------------------------
# NetworkXNotImplemented                    Traceback (most recent call last)
# <ipython-input-67-e8fde40bb493> in <module>
#      26 plt.show()
#      27
# ---> 28 nx.simple_cycles(G)
#
# </Users/gautamkakkar/anaconda3/envs/Virtual_Base/lib/python3.7/site-packages/decorator.py:decorator-gen-393> in simple_cycles(G)
#
# ~/anaconda3/envs/Virtual_Base/lib/python3.7/site-packages/networkx/utils/decorators.py in _not_implemented_for(not_implement_for_func, *args, **kwargs)
#      78         if match:
#      79             msg = 'not implemented for %s type' % ' '.join(graph_types)
# ---> 80             raise nx.NetworkXNotImplemented(msg)
#      81         else:
#      82             return not_implement_for_func(*args, **kwargs)
#
# NetworkXNotImplemented: not implemented for undirected type
